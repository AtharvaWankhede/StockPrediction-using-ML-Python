# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('book3.csv')

# %%
df.head()
# Out:
#                                  DATE        TIME       Infosys   Wipro  \
# 2021-01-27 11:56:50.171724                   1318.10     450.14  270.12
# 2021-01-27 11:57:01.398985                   1318.10     450.14  270.12
# 2021-01-27 11:57:13.114112                   1318.05     450.14  270.13
# 2021-01-27 11:57:24.085157                   1318.05     450.14  270.13
# 2021-01-27 11:57:35.069122                   1318.05     450.14  270.13
#
#                             TATA MOTORS  BAJAJ FINANCE  BANK OF INDIA   BIRLA  \
# 2021-01-27 11:56:50.171724      4864.26          50.07         719.48  385.03
# 2021-01-27 11:57:01.398985      4864.26          50.07         719.48  385.03
# 2021-01-27 11:57:13.114112      4864.26          50.07         719.49  385.03
# 2021-01-27 11:57:24.085157      4864.26          50.07         719.49  385.03
# 2021-01-27 11:57:35.069122      4864.26          50.07         719.49  385.03
#
#                                BOSCH     HDFC
# ...

# %%
df.tail()
# Out:
#                                  DATE        TIME       Infosys   Wipro  \
# 2021-01-27 13:16:40.075225                   1316.09     450.07  270.12
# 2021-01-27 13:16:51.292672                   1316.10     450.08  270.12
# 2021-01-27 13:17:02.269628                   1316.09     450.07  270.12
# 2021-01-27 13:17:13.288872                   1316.10     450.07  270.12
# 2021-01-27 13:17:24.281427                   1316.10     450.08  270.12
#
#                             TATA MOTORS  BAJAJ FINANCE  BANK OF INDIA   BIRLA  \
# 2021-01-27 13:16:40.075225      4863.54          50.04         719.29  385.98
# 2021-01-27 13:16:51.292672      4863.54          50.04         719.29  385.98
# 2021-01-27 13:17:02.269628      4863.53          50.04         719.29  385.98
# 2021-01-27 13:17:13.288872      4863.53          50.04         719.29  385.98
# 2021-01-27 13:17:24.281427      4863.53          50.04         719.29  385.98
#
#                                BOSCH     HDFC
# ...

# %%
#df1=df['Infosys']
#df2=df['Wipro']
#df3=df['TATA MOTORS']
#df4=df['BAJAJ FINANCE']
#df5=df['BANK OF INDIA']
#df6=df['BIRLA']
df7=df['BOSCH']
#df8=df['HDFC']

# %%
df7
# Out:
# 2021-01-27 11:56:50.171724    15772.01
# 2021-01-27 11:57:01.398985    15772.01
# 2021-01-27 11:57:13.114112    15771.93
# 2021-01-27 11:57:24.085157    15771.93
# 2021-01-27 11:57:35.069122    15772.19
#                                 ...
# 2021-01-27 13:16:40.075225    15781.28
# 2021-01-27 13:16:51.292672    15781.28
# 2021-01-27 13:17:02.269628    15781.28
# 2021-01-27 13:17:13.288872    15781.28
# 2021-01-27 13:17:24.281427    15781.28
# Name: BOSCH, Length: 428, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
#df1=scaler.fit_transform(np.array(df1).reshape(-1,1))
#df2=scaler.fit_transform(np.array(df2).reshape(-1,1))
#df3=scaler.fit_transform(np.array(df3).reshape(-1,1))
#df4=scaler.fit_transform(np.array(df4).reshape(-1,1))
#df5=scaler.fit_transform(np.array(df5).reshape(-1,1))
#df6=scaler.fit_transform(np.array(df6).reshape(-1,1))
df7=scaler.fit_transform(np.array(df7).reshape(-1,1))
#df8=scaler.fit_transform(np.array(df8).reshape(-1,1))

# %%
df7
# Out:
# array([[0.00855615],
#        [0.00855615],
#        [0.        ],
#        [0.        ],
#        [0.02780749],
#        [0.00855615],
#        [0.00855615],
#        [0.00855615],
#        [0.00855615],
#        [0.02780749],
#        [0.02780749],
#        [0.02780749],
#        [0.02780749],
#        [0.03957219],
#        [0.02780749],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.09518717],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
# ...

# %%
plt.plot(df7)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
#df1=scaler.fit_transform(np.array(df1).reshape(-1,1))
#df2=scaler.fit_transform(np.array(df2).reshape(-1,1))
#df3=scaler.fit_transform(np.array(df3).reshape(-1,1))
#df4=scaler.fit_transform(np.array(df4).reshape(-1,1))
#df5=scaler.fit_transform(np.array(df5).reshape(-1,1))
#df6=scaler.fit_transform(np.array(df6).reshape(-1,1))
df7=scaler.fit_transform(np.array(df7).reshape(-1,1))
#df8=scaler.fit_transform(np.array(df8).reshape(-1,1))

# %%
df7
# Out:
# array([[0.00855615],
#        [0.00855615],
#        [0.        ],
#        [0.        ],
#        [0.02780749],
#        [0.00855615],
#        [0.00855615],
#        [0.00855615],
#        [0.00855615],
#        [0.02780749],
#        [0.02780749],
#        [0.02780749],
#        [0.02780749],
#        [0.03957219],
#        [0.02780749],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.09518717],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
# ...

# %%
#TRAIN TEST SPLIT

# %%
#training_size1=int(len(df1)*0.65)
#test_size1=len(df1)-training_size1
#train_data1,test_data1=df1[0:training_size1,:],df1[training_size1:len(df1),:1]

#training_size2=int(len(df2)*0.65)
#test_size2=len(df2)-training_size2
#train_data2,test_data2=df2[0:training_size2,:],df2[training_size2:len(df2),:1]

#training_size3=int(len(df3)*0.65)
#test_size3=len(df3)-training_size3
#train_data3,test_data3=df3[0:training_size3,:],df3[training_size3:len(df3),:1]

#training_size4=int(len(df4)*0.65)
#test_size4=len(df4)-training_size4
#train_data4,test_data4=df4[0:training_size4,:],df4[training_size4:len(df4),:1]

#training_size5=int(len(df5)*0.65)
#test_size5=len(df5)-training_size5
#train_data5,test_data5=df5[0:training_size5,:],df5[training_size5:len(df5),:1]

#training_size6=int(len(df6)*0.65)
#test_size6=len(df6)-training_size6
#train_data6,test_data6=df6[0:training_size6,:],df6[training_size6:len(df6),:1]

training_size7=int(len(df7)*0.65)
test_size7=len(df7)-training_size7
train_data7,test_data7=df7[0:training_size7,:],df7[training_size7:len(df7),:1]

#training_size8=int(len(df8)*0.65)
#test_size8=len(df8)-training_size8
#train_data8,test_data8=df8[0:training_size8,:],df1[training_size8:len(df8),:1]

# %%
training_size7
# Out:
# 278

# %%
test_size7
# Out:
# 150

# %%
training_size7,test_size7
# Out:
# (278, 150)

# %%
train_data7
# Out:
# array([[0.00855615],
#        [0.00855615],
#        [0.        ],
#        [0.        ],
#        [0.02780749],
#        [0.00855615],
#        [0.00855615],
#        [0.00855615],
#        [0.00855615],
#        [0.02780749],
#        [0.02780749],
#        [0.02780749],
#        [0.02780749],
#        [0.03957219],
#        [0.02780749],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.03957219],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.08770053],
#        [0.09518717],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
#        [0.12299465],
# ...

# %%
#converting in dataset matrix--- dividing in x and y
import numpy

def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#reshaping
time_step = 100
X_train7, y_train7 = create_dataset(train_data7, time_step)
X_test7, ytest7 = create_dataset(test_data7, time_step)

# %%
print(X_train7)
# Out:
# [[0.00855615 0.00855615 0.         ... 0.19786096 0.19786096 0.19786096]
#  [0.00855615 0.         0.         ... 0.19786096 0.19786096 0.19786096]
#  [0.         0.         0.02780749 ... 0.19786096 0.19786096 0.19786096]
#  ...
#  [0.29197861 0.45347594 0.45347594 ... 0.86417112 0.86417112 0.86417112]
#  [0.45347594 0.45347594 0.45347594 ... 0.86417112 0.86417112 0.86417112]
#  [0.45347594 0.45347594 0.45347594 ... 0.86417112 0.86417112 0.86417112]]

# %%
print(y_train7)
# Out:
# [0.19786096 0.19786096 0.19786096 0.20320856 0.20320856 0.20320856
#  0.20320856 0.20320856 0.20320856 0.20320856 0.20320856 0.20320856
#  0.23208556 0.20320856 0.23208556 0.23208556 0.23208556 0.23208556
#  0.23208556 0.23208556 0.23208556 0.23208556 0.23208556 0.23208556
#  0.23208556 0.23208556 0.23208556 0.23208556 0.23208556 0.23208556
#  0.23208556 0.23208556 0.23208556 0.24919786 0.24919786 0.24919786
#  0.24919786 0.24919786 0.24919786 0.24919786 0.24919786 0.27165775
#  0.27165775 0.27165775 0.27165775 0.27165775 0.27165775 0.27165775
#  0.27165775 0.27165775 0.27165775 0.27165775 0.27165775 0.27486631
#  0.27486631 0.27486631 0.27807487 0.27807487 0.27486631 0.27807487
#  0.27807487 0.27486631 0.27807487 0.27807487 0.29197861 0.29197861
#  0.29197861 0.29197861 0.29197861 0.29197861 0.29197861 0.29197861
#  0.29197861 0.29197861 0.29197861 0.45347594 0.45347594 0.45347594
#  0.45347594 0.45347594 0.45347594 0.45347594 0.45347594 0.45347594
# ...

# %%
print(X_test7)
# Out:
# [[0.8684492  0.8684492  0.8684492  ... 0.96684492 0.96684492 0.96684492]
#  [0.8684492  0.8684492  0.8684492  ... 0.96684492 0.96684492 0.96684492]
#  [0.8684492  0.8684492  0.8684492  ... 0.96684492 0.96684492 0.96684492]
#  ...
#  [0.89197861 0.89197861 0.89197861 ... 1.         1.         1.        ]
#  [0.89197861 0.89197861 0.89197861 ... 1.         1.         1.        ]
#  [0.89197861 0.89197861 0.89197861 ... 1.         1.         1.        ]]

# %%
print(X_train7.shape), print(y_train7.shape)
# Out:
# (177, 100)
# (177,)
# (None, None)

# %%
print(X_test7.shape), print(ytest7.shape)
# Out:
# (49, 100)
# (49,)
# (None, None)

# %%
X_train7
# Out:
# array([[0.00855615, 0.00855615, 0.        , ..., 0.19786096, 0.19786096,
#         0.19786096],
#        [0.00855615, 0.        , 0.        , ..., 0.19786096, 0.19786096,
#         0.19786096],
#        [0.        , 0.        , 0.02780749, ..., 0.19786096, 0.19786096,
#         0.19786096],
#        ...,
#        [0.29197861, 0.45347594, 0.45347594, ..., 0.86417112, 0.86417112,
#         0.86417112],
#        [0.45347594, 0.45347594, 0.45347594, ..., 0.86417112, 0.86417112,
#         0.86417112],
#        [0.45347594, 0.45347594, 0.45347594, ..., 0.86417112, 0.86417112,
#         0.86417112]])

# %%
X_train7 =X_train7.reshape(X_train7.shape[0],X_train7.shape[1] , 1)
X_test7 = X_test7.reshape(X_test7.shape[0],X_test7.shape[1] , 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(X_train7,y_train7,validation_data=(X_test7,ytest7),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 4s 1s/step - loss: 0.2081 - val_loss: 0.2130
# Epoch 2/100
# 3/3 [==============================] - 1s 213ms/step - loss: 0.0288 - val_loss: 0.0606
# Epoch 3/100
# 3/3 [==============================] - 1s 176ms/step - loss: 0.0422 - val_loss: 0.0027
# Epoch 4/100
# 3/3 [==============================] - 1s 174ms/step - loss: 0.0088 - val_loss: 0.0540
# Epoch 5/100
# 3/3 [==============================] - 1s 169ms/step - loss: 0.0172 - val_loss: 0.0863
# Epoch 6/100
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0180 - val_loss: 0.0424
# Epoch 7/100
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0073 - val_loss: 0.0031
# Epoch 8/100
# 3/3 [==============================] - 1s 173ms/step - loss: 0.0068 - val_loss: 7.8028e-04
# Epoch 9/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0090 - val_loss: 3.4616e-04
# Epoch 10/100
# ...

# %%
tf.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-65996cac02ec> in <module>
# ----> 1 tf.__version__
#
# NameError: name 'tf' is not defined

# %%
train_predict7=model.predict(X_train7)
test_predict7=model.predict(X_test7)

# %%
train_predict7=scaler.inverse_transform(train_predict7)
test_predict7=scaler.inverse_transform(test_predict7)

# %%
#TRAIN DATA RMSE
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train7,train_predict7))
# Out:
# 0.03488062131694895

# %%
#TEST DATA RMSE
math.sqrt(mean_squared_error(ytest7,test_predict7))
# Out:
# 0.07039566336915382

# %%
### Plotting 
# shift train predictions for plotting
look_back=100#“lookback period” defines how many previous timesteps are used in order to predict the subsequent timestep.

# CREATING SIMILAR DATASET TO PLOT TRAINING PREDICTIONS
trainPredictPlot7 = numpy.empty_like(df7)#numpy.empty_like: Return a new array with the same shape and type as a given array.
trainPredictPlot7[:, :] = np.nan
trainPredictPlot7[look_back:len(train_predict7)+look_back, :] = train_predict7
# shift test predictions for plotting
testPredictPlot7 = numpy.empty_like(df7)
testPredictPlot7[:, :] = numpy.nan
testPredictPlot7[len(train_predict7)+(look_back*2)+1:len(df7)-1, :] = test_predict7
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df7))
plt.plot(trainPredictPlot7)
plt.plot(testPredictPlot7)
plt.show()


#BLUE ACTUAL DATA - how it VARIED 
#ORANGE -PREDICTED TRAIN O/p
#GREEN - PREDICTED TEST O/p

# %%
len(test_data7)
# Out:
# 150

# %%
len(train_data7)
# Out:
# 278

# %%
#taking data from 113 to 213 because we have taken timesteps as 100 and we will analyse previous 100 days output to get the next output
x_input=test_data7[50:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
#converting it into list
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])#shifting one position to right 
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        #passing 100 values to model and then predict 
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        #yhat-prediction 
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.92694134]
# 101
# 1 day input [0.91229947 0.91229947 0.91229947 0.91229947 0.91229947 0.91229947
#  0.91229947 0.91229947 0.91229947 0.93475936 0.93475936 0.93475936
#  0.93475936 0.93475936 0.93475936 0.94331551 0.94331551 0.93475936
#  0.94331551 0.94331551 0.94331551 0.94331551 0.94331551 0.94331551
#  0.94331551 0.94331551 0.9486631  0.94652406 0.94652406 0.9486631
#  0.94973262 0.9486631  0.9486631  0.9486631  0.94973262 0.94973262
#  0.96470588 0.94973262 0.96470588 0.96470588 0.96470588 0.96470588
#  0.96470588 0.96470588 0.96470588 0.96470588 0.96684492 0.96684492
#  0.96684492 0.96684492 0.96684492 0.96684492 0.96684492 0.96684492
#  0.96684492 0.98181818 0.98181818 0.98181818 0.98181818 0.98181818
#  0.98716578 0.98716578 0.98716578 0.98716578 0.98716578 0.98716578
#  0.98716578 0.98716578 0.98716578 0.98716578 0.99037433 0.98716578
#  0.99037433 0.99037433 0.99037433 0.99037433 0.99037433 0.99037433
#  0.99037433 0.99786096 0.99786096 0.99037433 0.99786096 0.99786096
# ...

# %%
#from previous data we kept 100 and thats why we took 100 indexes in daynew
day_new=np.arange(1,101)
day_pred=np.arange(101,131)#future 30 values

# %%
import matplotlib.pyplot as plt

# %%
len(df7)
# Out:
# 428

# %%
print(-100)
# Out:
# 1252

# %% [markdown]
# print(5755-100)

# %%
plt.plot(day_new,scaler.inverse_transform(df7[328:]))#taken previous 100 data to do future prediction  hence starting from 508 
#508-608 display as real data
plt.plot(day_pred,scaler.inverse_transform(lst_output))#adding lst op found
